# %% [markdown]
# <a href="https://colab.research.google.com/github/HaniyeDousti/Drug-Discovery/blob/main/DrugDiscovery_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Installing Libraries**

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 KB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (2.25.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.10)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 3.7 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, itsdangerous, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 itsdangerous-2.1.2 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# **Search for Target protein**

# %% [markdown]
# Target search for coronavirus

# %%
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 8   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 9   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
#
#                      organism  \
# 0                Homo sapiens
# 1                Homo sapiens
# 2     Drosophila melanogaster
# 3              Bemisia tabaci
# 4   Leptinotarsa decemlineata
# 5         Torpedo californica
# 6                Mus musculus
# 7           Rattus norvegicus
# 8    Electrophorus electricus
# 9                  Bos taurus
# 10          Anopheles gambiae
# 11     Nephotettix cincticeps
# 12              Gallus gallus
# 13                Danio rerio
# 14              Aedes aegypti
# 15            Musca domestica
# 16          Rattus norvegicus
# 17        Plutella xylostella
# 18            Musca domestica
# 19  Pediculus humanus capitis
# 20          Spodoptera litura
# 21      Laodelphax striatella
# 22        Schizaphis graminum
# 23     Caenorhabditis elegans
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   27.0
# 1                        Cholinesterases; ACHE & BCHE   27.0
# 2                                Acetylcholinesterase   18.0
# 3                                               AChE2   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   15.0
# 6                                Acetylcholinesterase   15.0
# 7                                Acetylcholinesterase   15.0
# 8                                Acetylcholinesterase   15.0
# 9                                Acetylcholinesterase   15.0
# 10                               Acetylcholinesterase   15.0
# 11               Ace-orthologous acetylcholinesterase   15.0
# 12                               Acetylcholinesterase   15.0
# 13                               Acetylcholinesterase   15.0
# 14                               Acetylcholinesterase   15.0
# 15                               Acetylcholinesterase   14.0
# 16  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 17                               Acetylcholinesterase   14.0
# 18                               Acetylcholinesterase   14.0
# 19                               Acetylcholinesterase   14.0
# 20                               Acetylcholinesterase   14.0
# 21                               Acetylcholinesterase   14.0
# 22                               Acetylcholinesterase   14.0
# 23                             Acetylcholinesterase 1   14.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL220
# 1                False    CHEMBL2095233
# 2                False    CHEMBL2242744
# 3                False    CHEMBL2366409
# 4                False    CHEMBL2366490
# 5                False       CHEMBL4780
# 6                False       CHEMBL3198
# 7                False       CHEMBL3199
# 8                False       CHEMBL4078
# 9                False       CHEMBL4768
# 10               False    CHEMBL2046266
# 11               False    CHEMBL2366514
# 12               False    CHEMBL3227914
# 13               False    CHEMBL3308995
# 14               False    CHEMBL4295607
# 15               False       CHEMBL5752
# 16               False    CHEMBL2111475
# 17               False    CHEMBL2242729
# 18               False    CHEMBL2242743
# 19               False    CHEMBL2362988
# 20               False    CHEMBL2366422
# 21               False    CHEMBL2366446
# 22               False    CHEMBL2366511
# 23               False    CHEMBL3341583
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 2   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 17  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 23  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     9606
# 1     9606
# 2     7227
# 3     7038
# 4     7539
# 5     7787
# 6    10090
# 7    10116
# 8     8005
# 9     9913
# 10    7165
# 11   94400
# 12    9031
# 13    7955
# 14    7159
# 15    7370
# 16   10116
# 17   51655
# 18    7370
# 19  121226
# 20   69820
# 21  195883
# 22   13262
# 23    6239

# %% [markdown]
# **Select and retrieve bioactivity data for SARS Coronavirus 3C-like proteinase (fifth entry)**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type='IC50')

# %%
df = pd.DataFrame.from_dict(res)
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        33969                  []    CHEMBL643384
# 1             None        37563                  []    CHEMBL643384
# 2             None        37565                  []    CHEMBL643384
#
#                                    assay_description assay_type  \
# 0  Inhibitory concentration against acetylcholine...          B
# 1  Inhibitory concentration against acetylcholine...          B
# 2  Inhibitory concentration against acetylcholine...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 1  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 2  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#    type  units    uo_units upper_value value
# 0  IC50     uM  UO_0000065        None  0.75
# 1  IC50     uM  UO_0000065        None   0.1
# 2  IC50     uM  UO_0000065        None  50.0
#
# [3 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
#  we will save the resulting bioactivity data to a CSV file bioactivity_data.csv.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %%
! head acetylcholinesterase_01_bioactivity_data_raw.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,33969,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '19.61', 'le': '0.36', 'lle': '3.32', 'sei': '9.21'}",CHEMBL133897,,CHEMBL133897,6.12,0,http://www.openphacts.org/units/Nanomolar,252547,=,1,1,=,,IC50,nM,,750.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.75
# ,37563,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '18.57', 'le': '0.38', 'lle': '2.45', 'sei': '13.72'}",CHEMBL336398,,CHEMBL336398,7.00,0,http://www.openphacts.org/units/Nanomolar,252533,=,1,1,=,,IC50,nM,,100.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.1
# ,37565,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1,,,CHEMBL1148382,J. Med. Chem.,2004.0,,CHEMBL131588,,CHEMBL131588,,0,http://www.openphacts.org/units/Nanomolar,252530,>,1,1,>,,IC50,nM,,50000.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,50.0
# ,38902,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '16.11', 'le': '0.34', 'lle': '1.81', 'sei': '12.78'}",CHEMBL130628,,CHEMBL130628,6.52,0,http://www.openphacts.org/units/Nanomolar,252534,=,1,1,=,,IC50,nM,,300.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.3
# ,41170,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '17.60', 'le': '0.36', 'lle': '3.00', 'sei': '10.12'}",CHEMBL130478,,CHEMBL130478,6.10,0,http://www.openphacts.org/units/Nanomolar,252552,=,1,1,=,,IC50,nM,,800.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.8
# ,42363,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CSc1nc(-c2ccc(C)cc2)nn1C(=O)N(C)c1ccccc1,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '16.60', 'le': '0.32', 'lle': '1.54', 'sei': '11.01'}",CHEMBL130112,,CHEMBL130112,5.62,0,http://www.openphacts.org/units/Nanomolar,252551,=,1,1,=,,IC50,nM,,2400.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,2.4
# ,43561,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N(C)C,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '23.59', 'le': '0.50', 'lle': '4.15', 'sei': '13.72'}",CHEMBL130098,,CHEMBL130098,7.00,0,http://www.openphacts.org/units/Nanomolar,252525,=,1,1,=,,IC50,nM,,100.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.1
# ,44825,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,CCCCCCSc1nc(-c2ccc(Cl)cc2)nn1C(=O)N1CCOCC1,,,CHEMBL1148382,J. Med. Chem.,2004.0,,CHEMBL337486,,CHEMBL337486,,0,http://www.openphacts.org/units/Nanomolar,252538,>,1,1,>,,IC50,nM,,50000.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,50.0
# ,45908,[],CHEMBL643384,Inhibitory concentration against acetylcholinesterase,B,,,BAO_0000190,BAO_0000357,single protein format,COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1,,,CHEMBL1148382,J. Med. Chem.,2004.0,"{'bei': '20.85', 'le': '0.42', 'lle': '3.89', 'sei': '10.12'}",CHEMBL336538,,CHEMBL336538,6.10,0,http://www.openphacts.org/units/Nanomolar,252527,=,1,1,=,,IC50,nM,,800.0,CHEMBL220,Homo sapiens,Acetylcholinesterase,9606,,,IC50,uM,UO_0000065,,0.8

# %% [markdown]
# **Handling missing data**

# %%
df['standard_value'].isnull().sum()
# Out:
# 1266

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-11-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      activity_comment  activity_id  \
# 0                None        33969
# 1                None        37563
# 2                None        37565
# 3                None        38902
# 4                None        41170
# ...               ...          ...
# 8387             None     23311838
# 8388             None     23311839
# 8389             None     23311840
# 8390             None     23311841
# 8392             None     23311843
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL643384
# 1                                                    []    CHEMBL643384
# 2                                                    []    CHEMBL643384
# 3                                                    []    CHEMBL643384
# 4                                                    []    CHEMBL643384
# ...                                                 ...             ...
# 8387  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4844259
# 8388  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4844259
# 8389  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4844259
# 8390  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4844259
# 8392  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4844259
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 8387  Inhibition of human recombinant AChE using ace...          B
# 8388  Inhibition of human recombinant AChE using ace...          B
# 8389  Inhibition of human recombinant AChE using ace...          B
# 8390  Inhibition of human recombinant AChE using ace...          B
# 8392  Inhibition of human recombinant AChE using ace...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000357
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000357
# 3                       None                   None  BAO_0000190  BAO_0000357
# 4                       None                   None  BAO_0000190  BAO_0000357
# ...                      ...                    ...          ...          ...
# 8387                    None                   None  BAO_0000190  BAO_0000357
# 8388                    None                   None  BAO_0000190  BAO_0000357
# 8389                    None                   None  BAO_0000190  BAO_0000357
# 8390                    None                   None  BAO_0000190  BAO_0000357
# 8392                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 1     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 2     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 3     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 4     ...    Homo sapiens  Acetylcholinesterase          9606       None
# ...   ...             ...                   ...           ...        ...
# 8387  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 8388  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 8389  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 8390  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 8392  ...    Homo sapiens  Acetylcholinesterase          9606       None
#
#       toid  type  units    uo_units upper_value value
# 0     None  IC50     uM  UO_0000065        None  0.75
# 1     None  IC50     uM  UO_0000065        None   0.1
# 2     None  IC50     uM  UO_0000065        None  50.0
# 3     None  IC50     uM  UO_0000065        None   0.3
# 4     None  IC50     uM  UO_0000065        None   0.8
# ...    ...   ...    ...         ...         ...   ...
# 8387  None  IC50     nM  UO_0000065        None  0.63
# 8388  None  IC50     nM  UO_0000065        None  1.25
# 8389  None  IC50     nM  UO_0000065        None   3.6
# 8390  None  IC50     nM  UO_0000065        None  1.07
# 8392  None  IC50     nM  UO_0000065        None  26.8
#
# [7127 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 5824

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
len(df2_nr)
# Out:
# 5824

# %% [markdown]
# **Pre-Processing of the bioactivity data**

# %% [markdown]
# Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 8384      CHEMBL4859103  CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCCNC(=O)c4cc(...
# 8385      CHEMBL4863615  CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)Nc4cn[n...
# 8386      CHEMBL4854913  CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)N4CCNC(...
# 8387      CHEMBL4848527  CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)NCc4cc[...
# 8388      CHEMBL4872514  COc1cc(CNC(=O)CCCCCCCCNc2c3c(nc4cc(Cl)ccc24)CC...
#
#      standard_value
# 0             750.0
# 1             100.0
# 2           50000.0
# 3             300.0
# 4             800.0
# ...             ...
# 8384           2.57
# 8385           2.39
# 8386           0.41
# 8387           0.63
# 8388           1.25
#
# [5824 rows x 3 columns]

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append('inactive')
  elif float(i) <= 1000:
    bioactivity_threshold.append('active')
  else:
    bioactivity_threshold.append('intermediate')

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 7122                NaN                                                NaN
# 7123                NaN                                                NaN
# 7124                NaN                                                NaN
# 7125                NaN                                                NaN
# 7126                NaN                                                NaN
#
#       standard_value     class
# 0              750.0    active
# 1              100.0    active
# 2            50000.0  inactive
# 3              300.0    active
# 4              800.0    active
# ...              ...       ...
# 7122             NaN    active
# 7123             NaN    active
# 7124             NaN    active
# 7125             NaN    active
# 7126             NaN    active
#
# [7127 rows x 4 columns]

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 5836
# -rw-r--r-- 1 root root 4458046 Feb  1 19:01 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  427580 Feb  1 19:21 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  495345 Feb  1 19:24 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  581858 Feb  1 19:25 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 Jan 31 14:44 sample_data
